# %%
pip install google-play-scraper pandas
# Out:
# Requirement already satisfied: google-play-scraper in d:\softwares\anaconda\lib\site-packages (1.2.7)
# Requirement already satisfied: pandas in d:\softwares\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\softwares\anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\softwares\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\softwares\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\softwares\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\softwares\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime, date, time, timedelta

# %%
from google_play_scraper import Sort, reviews
import pandas as pd

result, _ = reviews(
    'com.cgt.bharatgas',  # Replace with real app ID
    lang='en',
    country='IN',
    sort=Sort.NEWEST,
    count=20000
)

df = pd.DataFrame(result)
df[['userName', 'score', 'at', 'content']].to_csv('playstore_reviews.csv', index=False)

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  b1a8eac5-4ff7-457d-861a-fc40be50c0b3  A Google user
# 1  03eaa7f0-4ac0-45e8-92c3-e380673b8d91  A Google user
# 2  34aeb9a1-661e-45fb-a052-21dede7c04cb  A Google user
# 3  58aaf48e-eaa7-4df2-bfc4-844f5b98ff36  A Google user
# 4  213ab120-b0e2-4fd8-bb18-d9dba6035f22  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                                               good      4              0
# 1                                      very nice app      5              0
# 2                                  very Useful App's      5              0
# 3                                               good      4              0
# 4  I am not happy to redeem BPCL credit card poin...      1              0
#
#   reviewCreatedVersion                  at  \
# 0               4.0.64 2025-06-19 16:29:01
# 1               4.0.64 2025-06-19 16:26:04
# 2               4.0.64 2025-06-19 15:50:23
# 3               4.0.64 2025-06-19 15:43:21
# 4               4.0.64 2025-06-19 15:12:35
#
#                                         replyContent           repliedAt  \
# 0  Hi Shabir,\nWe are happy to hear your feedback... 2025-05-30 14:24:32
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4                                               None                 NaT
#
#   appVersion
# 0     4.0.64
# 1     4.0.64
# 2     4.0.64
# 3     4.0.64
# 4     4.0.64

# %%
df=df.drop("reviewId",axis=1)

# %%
df=df.drop("userName",axis=1)
df=df.drop("userImage",axis=1)
df=df.drop("replyContent",axis=1)
df=df.drop("repliedAt",axis=1)

# %%
df
# Out:
#                                                  content  score  \
# 0                                                   good      4
# 1                                          very nice app      5
# 2                                      very Useful App's      5
# 3                                                   good      4
# 4      I am not happy to redeem BPCL credit card poin...      1
# ...                                                  ...    ...
# 19995                                          Excellent      5
# 19996                                               Good      4
# 19997                                               Good      5
# 19998              Excellent experience too easy to work      5
# 19999                                        Easy to use      5
#
#        thumbsUpCount reviewCreatedVersion                  at appVersion
# 0                  0               4.0.64 2025-06-19 16:29:01     4.0.64
# 1                  0               4.0.64 2025-06-19 16:26:04     4.0.64
# 2                  0               4.0.64 2025-06-19 15:50:23     4.0.64
# 3                  0               4.0.64 2025-06-19 15:43:21     4.0.64
# 4                  0               4.0.64 2025-06-19 15:12:35     4.0.64
# ...              ...                  ...                 ...        ...
# 19995              0               4.0.54 2024-10-05 10:09:34     4.0.54
# 19996              0               4.0.54 2024-10-05 10:06:40     4.0.54
# 19997              0               4.0.54 2024-10-05 09:57:20     4.0.54
# 19998              0               4.0.54 2024-10-05 09:56:30     4.0.54
# 19999              0               4.0.54 2024-10-05 09:55:45     4.0.54
#
# [20000 rows x 6 columns]

# %%
df.to_csv('playstore_reviews.csv', index=False)

# %%
df.to_csv('C:/Users/Prateek Kumar/Downloads/output.csv', index=False)

# %% [markdown]
# #Sentiment Analysis

# %%
! pip install pandas textblob nltk matplotlib
# Out:
# Requirement already satisfied: pandas in d:\softwares\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: textblob in d:\softwares\anaconda\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk in d:\softwares\anaconda\lib\site-packages (3.9.1)
# Requirement already satisfied: matplotlib in d:\softwares\anaconda\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\softwares\anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\softwares\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\softwares\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\softwares\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: click in d:\softwares\anaconda\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in d:\softwares\anaconda\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\softwares\anaconda\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in d:\softwares\anaconda\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: contourpy>=1.0.1 in d:\softwares\anaconda\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\softwares\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\softwares\anaconda\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\softwares\anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\softwares\anaconda\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in d:\softwares\anaconda\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\softwares\anaconda\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in d:\softwares\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in d:\softwares\anaconda\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Prateek
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Prateek Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
import re

# %%
# Download stopwords list
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Prateek
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('HelloBPCL Reviews.csv')

# %%
df
# Out:
#                                                  content  score  \
# 0                                                   good      4
# 1                                          very nice app      5
# 2                                      very Useful App's      5
# 3                                                   good      4
# 4      I am not happy to redeem BPCL credit card poin...      1
# ...                                                  ...    ...
# 19995                                          Excellent      5
# 19996                                               Good      4
# 19997                                               Good      5
# 19998              Excellent experience too easy to work      5
# 19999                                        Easy to use      5
#
#        thumbsUpCount reviewCreatedVersion                   at appVersion
# 0                  0               4.0.64  2025-06-19 16:29:01     4.0.64
# 1                  0               4.0.64  2025-06-19 16:26:04     4.0.64
# 2                  0               4.0.64  2025-06-19 15:50:23     4.0.64
# 3                  0               4.0.64  2025-06-19 15:43:21     4.0.64
# 4                  0               4.0.64  2025-06-19 15:12:35     4.0.64
# ...              ...                  ...                  ...        ...
# 19995              0               4.0.54  2024-10-05 10:09:34     4.0.54
# 19996              0               4.0.54  2024-10-05 10:06:40     4.0.54
# 19997              0               4.0.54  2024-10-05 09:57:20     4.0.54
# 19998              0               4.0.54  2024-10-05 09:56:30     4.0.54
# 19999              0               4.0.54  2024-10-05 09:55:45     4.0.54
#
# [20000 rows x 6 columns]

# %%
def clean_text(df):
    # Remove special characters and numbers
    df = re.sub(r"[^a-zA-Z\s]", "", df)
    # Convert to lowercase and split into words
    words = df.lower().split()
    # Remove stopwords
    cleaned_words = [word for word in words if word not in stop_words]
    return " ".join(cleaned_words)

df['cleaned_review'] = df['content'].astype(str).apply(clean_text)

full_text = " ".join(df['cleaned_review'])
#cleaned_text = clean_text(df)
#print(cleaned_text)


wordcloud = WordCloud(
    width=1000,
    height=500,
    background_color='white',
    colormap='jet',
    max_words=150,
    contour_color='viridis',
    contour_width=3
).generate(full_text)
plt.figure(figsize=(12, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud of HelloBPCl App Reviews", fontsize=20)
plt.show()

# %%
plt.savefig("C:/Users/Prateek Kumar/Downloads/output.png", dpi=300)

# %%
df = df.dropna(subset=['content'])

# %%
df
# Out:
#                                                  content  score  \
# 0                                                   good      4
# 1                                          very nice app      5
# 2                                      very Useful App's      5
# 3                                                   good      4
# 4      I am not happy to redeem BPCL credit card poin...      1
# ...                                                  ...    ...
# 19995                                          Excellent      5
# 19996                                               Good      4
# 19997                                               Good      5
# 19998              Excellent experience too easy to work      5
# 19999                                        Easy to use      5
#
#        thumbsUpCount reviewCreatedVersion                   at appVersion  \
# 0                  0               4.0.64  2025-06-19 16:29:01     4.0.64
# 1                  0               4.0.64  2025-06-19 16:26:04     4.0.64
# 2                  0               4.0.64  2025-06-19 15:50:23     4.0.64
# 3                  0               4.0.64  2025-06-19 15:43:21     4.0.64
# 4                  0               4.0.64  2025-06-19 15:12:35     4.0.64
# ...              ...                  ...                  ...        ...
# 19995              0               4.0.54  2024-10-05 10:09:34     4.0.54
# 19996              0               4.0.54  2024-10-05 10:06:40     4.0.54
# 19997              0               4.0.54  2024-10-05 09:57:20     4.0.54
# 19998              0               4.0.54  2024-10-05 09:56:30     4.0.54
# 19999              0               4.0.54  2024-10-05 09:55:45     4.0.54
#
#                                           cleaned_review
# 0                                                   good
# 1                                               nice app
# 2                                            useful apps
# 3                                                   good
# 4      happy redeem bpcl credit card points bharath p...
# ...                                                  ...
# 19995                                          excellent
# 19996                                               good
# 19997                                               good
# 19998                     excellent experience easy work
# 19999                                           easy use
#
# [20000 rows x 7 columns]

# %%
# Function to calculate polarity
def get_sentiment(df):
    blob = TextBlob(df)
    return blob.sentiment.polarity

# %%
# Apply sentiment analysis
df['Polarity'] = df['content'].apply(get_sentiment)

# %%
df['Polarity']
# Out:
# 0        0.700000
# 1        0.780000
# 2        0.390000
# 3        0.700000
# 4       -0.700000
#            ...
# 19995    1.000000
# 19996    0.700000
# 19997    0.700000
# 19998    0.716667
# 19999    0.433333
# Name: Polarity, Length: 20000, dtype: float64

# %%
# Classify sentiment
def classify_sentiment(score):
    if score > 0.2:
        return 'Positive'
    elif score < -0.2:
        return 'Negative'
    else:
        return 'Neutral'

df['Sentiment'] = df['Polarity'].apply(classify_sentiment)

# %%
# Show sample results
print(df[['content', 'Polarity', 'Sentiment']])
# Out:
#                                                  content  Polarity Sentiment
# 0                                                   good  0.700000  Positive
# 1                                          very nice app  0.780000  Positive
# 2                                      very Useful App's  0.390000  Positive
# 3                                                   good  0.700000  Positive
# 4      I am not happy to redeem BPCL credit card poin... -0.700000  Negative
# ...                                                  ...       ...       ...
# 19995                                          Excellent  1.000000  Positive
# 19996                                               Good  0.700000  Positive
# 19997                                               Good  0.700000  Positive
# 19998              Excellent experience too easy to work  0.716667  Positive
# 19999                                        Easy to use  0.433333  Positive
#
# [20000 rows x 3 columns]

# %%
# Optional: Plot sentiment distribution
sentiment_counts = df['Sentiment'].value_counts()
sentiment_counts.plot(kind='bar', color=['lightgreen', 'pink', 'skyblue'])
plt.title('Sentiment Distribution of HelloBPCL App Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
